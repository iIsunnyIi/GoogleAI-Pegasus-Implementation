# %% [markdown]
# <a href="https://colab.research.google.com/github/iIsunnyIi/GoogleAI-Pegasus-Implementation/blob/main/Google_Pegasus_Implementation_with_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Here We have Implemented Pegasus Pre-trained models which are trained on various datasets.
# ================================================================================
# ### I have taken a random query from stackover flow as our goal is to find the best model which works well with skype support queries.
#
# we can change the query in the text :
#
#
# # text = [ " CHANGE TEXT HERE " ]
#
# in this cell and can rerun all the models.
#
# Model taken into consideration :
#
# 1) xsum
#
# 2) large
#
# 3) reddit_tifu
#
# 4) pegasus-wikihow
#
# 5) pegasus-arxiv
#
# 6) egasus-aeslc
#
#
# ## @author: Sunny Gupta, Purvansh Singh

# %%
# !pip install Transformers==3.5
# Out:
# ...
#      |████████████████████████████████| 1.3MB 12.5MB/s
# ...
#      |████████████████████████████████| 2.9MB 47.9MB/s
# ...
#      |████████████████████████████████| 890kB 48.0MB/s
# ...
#      |████████████████████████████████| 1.1MB 43.8MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=b5adb16029bf34ab81ddec6f81aeb8cd161dc75c9df3f608aab0ffd5b1153d4d
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
# !pip install pytorch-transformers
# Out:
# ...
#      |████████████████████████████████| 184kB 12.3MB/s
# ...
#      |████████████████████████████████| 133kB 21.7MB/s
# ...
#      |████████████████████████████████| 7.0MB 22.1MB/s
# ...
#      |████████████████████████████████| 71kB 8.8MB/s
# ...
# ERROR: botocore 1.19.28 has requirement urllib3<1.27,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# ...

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
import torch

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
text = [
        "I am currently learning some machine learning and I know how to calculate\
         the euclidean distance between different data points; however, I was wondering\
          if anyone knows how to calculate the accuracy by hand in order to see which k-value is the best as the choice of k?\
          I know how to implement basic python classes to calculate the accuracy for me, but want to learn how to do it by hand as well.\
           I tried googling it, but they all just show python implementations.For instance, let's pretend you only have 8 data points,\
            4 red and 4 orange; I pick for instance k = 3 and get 2 red and 1 orange (so the new data point is classified as red).\
             Now I want to calculate the accuracy of this K value?"
]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model_name = 'google/pegasus-xsum'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)

# %%
batch = tokenizer.prepare_seq2seq_batch(text, truncation=True, padding='longest').to(torch_device)
translated = model.generate(**batch)
tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
print(tgt_text)
# Out:
# ['How to calculate the accuracy of the euclidean distance between different data points?']

# %%
model_name = 'google/pegasus-large'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)

# %%
batch = tokenizer.prepare_seq2seq_batch(text, truncation=True, padding='longest').to(torch_device)
translated = model.generate(**batch)
tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
print(tgt_text)
# Out:
# ['I am currently learning some machine learning and I know how to calculate the euclidean distance between different data points; however, I was wondering if anyone knows how to calculate the accuracy by hand in order to see which k-value is the best as the choice of k?']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
model_name = 'google/pegasus-reddit_tifu'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)

# %%
batch = tokenizer.prepare_seq2seq_batch(text, truncation=True, padding='longest').to(torch_device)
translated = model.generate(**batch)
tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
print(tgt_text)
# Out:
# ["i want to calculate the accuracy of a k value by hand, but i don't know how to do it in python, so i'm not sure how to do it."]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = AutoTokenizer.from_pretrained("google/pegasus-wikihow")
model = AutoModelForSeq2SeqLM.from_pretrained("google/pegasus-wikihow")

# %%
batch = tokenizer.prepare_seq2seq_batch(text, truncation=True, padding='longest').to(torch_device)
translated = model.generate(**batch)
tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
print(tgt_text)
# Out:
# ['Is there a way to calculate the accuracy by hand for a situation where you need to pick a k-value based on a given set of data points?']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
tokenizer = AutoTokenizer.from_pretrained("google/pegasus-arxiv")
model = AutoModelForSeq2SeqLM.from_pretrained("google/pegasus-arxiv")

# %%
tch = tokenizer.prepare_seq2seq_batch(text, truncation=True, padding='longest').to(torch_device)
translated = model.generate(**batch)
tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
print(tgt_text)
# Out:
# ['we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclide
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
tokenizer = AutoTokenizer.from_pretrained("google/pegasus-aeslc")
model = AutoModelForSeq2SeqLM.from_pretrained("google/pegasus-aeslc")

# %%
tch = tokenizer.prepare_seq2seq_batch(text, truncation=True, padding='longest').to(torch_device)
translated = model.generate(**batch)
tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
print(tgt_text)
# Out:
# ['distance between data points']

# %% [markdown]
# # Results
#
# ## Best Result are shown by pegasus-wikihow model.
#
# 1) xsum :
#
# How to calculate the accuracy of the euclidean distance between different data points?
#
# 2) large :
#
# 'I am currently learning some machine learning and I know how to calculate the euclidean distance between different data points; however, I was wondering if anyone knows how to calculate the accuracy by hand in order to see which k-value is the best as the choice of k?
#
# 3) reddit_tifu :
#
# i want to calculate the accuracy of a k value by hand, but i don't know how to do it in python, so i'm not sure how to do it
#
# 4) pegasus-wikihow :
#
# Is there a way to calculate the accuracy by hand for a situation where you need to pick a k-value based on a given set of data points?
#
# 5) pegasus-arxiv :
#
# we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points using python. <n> we show how to calculate the euclidean distance between different data points
#
#
# 6) egasus-aeslc :
#
# distance between data points
